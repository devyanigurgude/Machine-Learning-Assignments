# %% [markdown]
# **Name**: Devyani Sanjay Gurgude **Div**: SEDA **Roll**: 09 **PRN no**:1252090009

# %% [markdown]
# **Assignment No: 01**
#
# Perform the following operations using Python on suitable data sets:
#
# 1.Read data from different formats (like csv, xls)
#
# 2.Find Shape of Data
#
# 3.Find Missing Values
#
# 4.Find data type of each column
#
# 5.Finding out Zero's
#
# 6.Indexing and selecting data, sort data,
#
# 7.Describe attributes of data, checking data types of each column,
#
# 8.counting unique values of data, format of each column, converting
# variable data type (e.g. from long to short, vice versa)

# %%
import pandas as pd
import numpy as np
house_df = pd.read_csv("house_price.csv")
house_df
# Out:
#    House_ID   Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 0         1       Pune       2.0          1      850.0        2015        1
# 1         2     Mumbai       NaN          2     1200.0        2012        1
# 2         3      Delhi       4.0          3     1800.0        2018        2
# 3         4  Bangalore       3.0          2        NaN        2016        1
# 4         5    Chennai       2.0          1      900.0        2010        0
# 5         6       Pune       3.0          2     1400.0        2019        1
# 6         7     Mumbai       4.0          3     2000.0        2014        2
# 7         8      Delhi       2.0          1      800.0        2008        0
#
#    Price_Lakhs
# 0           45
# 1          120
# 2           95
# 3           85
# 4           60
# 5           78
# 6          150
# 7           55

# %% [markdown]
# Find Shape of Data

# %%
house_df.shape
# Out:
# (8, 8)

# %% [markdown]
# Find Missing Values

# %%
house_df.isnull().sum()
# Out:
# House_ID       0
# Location       0
# Bedrooms       1
# Bathrooms      0
# Area_sqft      1
# Year_Built     0
# Parking        0
# Price_Lakhs    0
# dtype: int64

# %% [markdown]
# If missing values exist

# %%
house_df.isnull().values.any()
# Out:
# np.True_

# %% [markdown]
# Find datatype of each column

# %%
house_df.dtypes
# Out:
# House_ID          int64
# Location       category
# Bedrooms        float64
# Bathrooms       float64
# Area_sqft       float64
# Year_Built        int64
# Parking           int64
# Price_Lakhs       int64
# dtype: object

# %% [markdown]
# Finding Out Zero's

# %%
(house_df==0).sum()
# Out:
# House_ID       0
# Location       0
# Bedrooms       0
# Bathrooms      0
# Area_sqft      0
# Year_Built     0
# Parking        2
# Price_Lakhs    0
# dtype: int64

# %%
(house_df.select_dtypes(include=np.number) == 0).sum()
# Out:
# House_ID       0
# Bedrooms       0
# Bathrooms      0
# Area_sqft      0
# Year_Built     0
# Parking        2
# Price_Lakhs    0
# dtype: int64

# %% [markdown]
# Indexing ,Selecting , Sorting

# %%
house_df.head()
# Out:
#    House_ID   Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 0         1       Pune       2.0          1      850.0        2015        1
# 1         2     Mumbai       NaN          2     1200.0        2012        1
# 2         3      Delhi       4.0          3     1800.0        2018        2
# 3         4  Bangalore       3.0          2        NaN        2016        1
# 4         5    Chennai       2.0          1      900.0        2010        0
#
#    Price_Lakhs
# 0           45
# 1          120
# 2           95
# 3           85
# 4           60

# %%
house_df.tail()
# Out:
#    House_ID   Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 3         4  Bangalore       3.0          2        NaN        2016        1
# 4         5    Chennai       2.0          1      900.0        2010        0
# 5         6       Pune       3.0          2     1400.0        2019        1
# 6         7     Mumbai       4.0          3     2000.0        2014        2
# 7         8      Delhi       2.0          1      800.0        2008        0
#
#    Price_Lakhs
# 3           85
# 4           60
# 5           78
# 6          150
# 7           55

# %% [markdown]
# Select Rows using Index

# %%
house_df.iloc[0]
# Out:
# House_ID           1
# Location        Pune
# Bedrooms         2.0
# Bathrooms          1
# Area_sqft      850.0
# Year_Built      2015
# Parking            1
# Price_Lakhs       45
# Name: 0, dtype: object

# %%
house_df.iloc[0:3]
# Out:
#    House_ID Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 0         1     Pune       2.0          1      850.0        2015        1
# 1         2   Mumbai       NaN          2     1200.0        2012        1
# 2         3    Delhi       4.0          3     1800.0        2018        2
#
#    Price_Lakhs
# 0           45
# 1          120
# 2           95

# %%
house_df.iloc[2,3]
# Out:
# np.int64(3)

# %%
house_df.loc[0:3, ["Location", "Price_Lakhs"]]
# Out:
#     Location  Price_Lakhs
# 0       Pune           45
# 1     Mumbai          120
# 2      Delhi           95
# 3  Bangalore           85

# %% [markdown]
# Select a Single Column

# %%
house_df['Location']
# Out:
# 0         Pune
# 1       Mumbai
# 2        Delhi
# 3    Bangalore
# 4      Chennai
# 5         Pune
# 6       Mumbai
# 7        Delhi
# Name: Location, dtype: object

# %% [markdown]
# Select Multiple Column

# %%
house_df[['House_ID','Year_Built']]
# Out:
#    House_ID  Year_Built
# 0         1        2015
# 1         2        2012
# 2         3        2018
# 3         4        2016
# 4         5        2010
# 5         6        2019
# 6         7        2014
# 7         8        2008

# %% [markdown]
# Select Row using Condition

# %%
house_df[house_df['Location']=='Pune']
# Out:
#    House_ID Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 0         1     Pune       2.0          1      850.0        2015        1
# 5         6     Pune       3.0          2     1400.0        2019        1
#
#    Price_Lakhs
# 0           45
# 5           78

# %% [markdown]
# Sort Data

# %%
house_df.sort_values(by='Price_Lakhs')
# Out:
#    House_ID   Location  Bedrooms  Bathrooms  Area_sqft  Year_Built  Parking  \
# 0         1       Pune       2.0          1      850.0        2015        1
# 7         8      Delhi       2.0          1      800.0        2008        0
# 4         5    Chennai       2.0          1      900.0        2010        0
# 5         6       Pune       3.0          2     1400.0        2019        1
# 3         4  Bangalore       3.0          2        NaN        2016        1
# 2         3      Delhi       4.0          3     1800.0        2018        2
# 1         2     Mumbai       NaN          2     1200.0        2012        1
# 6         7     Mumbai       4.0          3     2000.0        2014        2
#
#    Price_Lakhs
# 0           45
# 7           55
# 4           60
# 5           78
# 3           85
# 2           95
# 1          120
# 6          150

# %% [markdown]
# Describe Attribute Of Data

# %%
house_df.describe()
# Out:
#        House_ID  Bedrooms  Bathrooms    Area_sqft   Year_Built   Parking  \
# count   8.00000  7.000000   8.000000     7.000000     8.000000  8.000000
# mean    4.50000  2.857143   1.875000  1278.571429  2014.000000  1.000000
# std     2.44949  0.899735   0.834523   477.717789     3.817254  0.755929
# min     1.00000  2.000000   1.000000   800.000000  2008.000000  0.000000
# 25%     2.75000  2.000000   1.000000   875.000000  2011.500000  0.750000
# 50%     4.50000  3.000000   2.000000  1200.000000  2014.500000  1.000000
# 75%     6.25000  3.500000   2.250000  1600.000000  2016.500000  1.250000
# max     8.00000  4.000000   3.000000  2000.000000  2019.000000  2.000000
#
#        Price_Lakhs
# count     8.000000
# mean     86.000000
# std      35.286582
# min      45.000000
# 25%      58.750000
# 50%      81.500000
# 75%     101.250000
# max     150.000000

# %% [markdown]
# Datatype of each column

# %%
house_df['Price_Lakhs'].dtype
# Out:
# dtype('int64')

# %%
house_df['Location'].dtype
# Out:
# dtype('O')

# %%
house_df.dtypes
# Out:
# House_ID         int64
# Location        object
# Bedrooms       float64
# Bathrooms        int64
# Area_sqft      float64
# Year_Built       int64
# Parking          int64
# Price_Lakhs      int64
# dtype: object

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   House_ID     8 non-null      int64
#  1   Location     8 non-null      object
#  2   Bedrooms     7 non-null      float64
#  3   Bathrooms    8 non-null      int64
#  4   Area_sqft    7 non-null      float64
#  5   Year_Built   8 non-null      int64
#  6   Parking      8 non-null      int64
#  7   Price_Lakhs  8 non-null      int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 644.0+ bytes

# %% [markdown]
# Counting Unique Values

# %%
house_df.nunique()
# Out:
# House_ID       8
# Location       5
# Bedrooms       3
# Bathrooms      3
# Area_sqft      7
# Year_Built     8
# Parking        3
# Price_Lakhs    8
# dtype: int64

# %%
house_df["Location"].unique()
# Out:
# array(['Pune', 'Mumbai', 'Delhi', 'Bangalore', 'Chennai'], dtype=object)

# %%
house_df["Location"].value_counts()
# Out:
# Location
# Pune         2
# Mumbai       2
# Delhi        2
# Bangalore    1
# Chennai      1
# Name: count, dtype: int64

# %% [markdown]
# Convert Variable Datatype

# %%
house_df['Bathrooms'] = house_df['Bathrooms'].astype(float)

# %% [markdown]
# Convert object to category

# %%
house_df["Location"] = house_df["Location"].astype("category")

# %%
house_df.dtypes
# Out:
# House_ID          int64
# Location       category
# Bedrooms        float64
# Bathrooms       float64
# Area_sqft       float64
# Year_Built        int64
# Parking           int64
# Price_Lakhs       int64
# dtype: object

# %% [markdown]
# Student DataFrame

# %%
import pandas as pd
data = {
    "Student_ID": [101, 102, 103, 104, 105],
    "Name": ["Amit", "Sneha", "Rahul", "Pooja", "Kiran"],
    "Age": [19, 20, 21, 20, 22],
    "Gender": ["Male", "Female", "Male", "Female", "Male"],
    "Department": ["CSE", "IT", "ECE", "CSE", "ME"],
    "Marks": [85, 92, 78, 88, 74],
    "Attendance (%)": [90, 95, 85, 92, 80],
    "Internship": ["Yes", "Yes", "No", "Yes", "No"]
}
df = pd.DataFrame(data)
df
# Out:
#    Student_ID   Name  Age  Gender Department  Marks  Attendance (%) Internship
# 0         101   Amit   19    Male        CSE     85              90        Yes
# 1         102  Sneha   20  Female         IT     92              95        Yes
# 2         103  Rahul   21    Male        ECE     78              85         No
# 3         104  Pooja   20  Female        CSE     88              92        Yes
# 4         105  Kiran   22    Male         ME     74              80         No

# %% [markdown]
# Find Shape of Data

# %%
df.shape
# Out:
# (5, 8)

# %% [markdown]
# Find Missing Values

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Name              0
# Age               0
# Gender            0
# Department        0
# Marks             0
# Attendance (%)    0
# Internship        0
# dtype: int64

# %% [markdown]
# Find Datatype of each column

# %%
df.dtypes
# Out:
# Student_ID         int64
# Name              object
# Age                int64
# Gender            object
# Department        object
# Marks              int64
# Attendance (%)     int64
# Internship        object
# dtype: object

# %% [markdown]
# Indexing , Selecting , Sorting Data

# %%
df.head()
# Out:
#    Student_ID   Name  Age  Gender Department  Marks  Attendance (%) Internship
# 0         101   Amit   19    Male        CSE     85              90        Yes
# 1         102  Sneha   20  Female         IT     92              95        Yes
# 2         103  Rahul   21    Male        ECE     78              85         No
# 3         104  Pooja   20  Female        CSE     88              92        Yes
# 4         105  Kiran   22    Male         ME     74              80         No

# %%
df.tail()
# Out:
#    Student_ID   Name  Age  Gender Department  Marks  Attendance (%) Internship
# 0         101   Amit   19    Male        CSE     85              90        Yes
# 1         102  Sneha   20  Female         IT     92              95        Yes
# 2         103  Rahul   21    Male        ECE     78              85         No
# 3         104  Pooja   20  Female        CSE     88              92        Yes
# 4         105  Kiran   22    Male         ME     74              80         No

# %% [markdown]
# Select Rows using Index

# %%
df.iloc[0]
# Out:
# Student_ID         101
# Name              Amit
# Age                 19
# Gender            Male
# Department         CSE
# Marks               85
# Attendance (%)      90
# Internship         Yes
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#    Student_ID   Name  Age  Gender Department  Marks  Attendance (%) Internship
# 0         101   Amit   19    Male        CSE     85              90        Yes
# 1         102  Sneha   20  Female         IT     92              95        Yes
# 2         103  Rahul   21    Male        ECE     78              85         No

# %%
df.iloc[1,3]
# Out:
# 'Female'

# %% [markdown]
# Select single row

# %%
df['Student_ID']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: Student_ID, dtype: int64

# %% [markdown]
# Select multiple rows

# %%
df[['Age','Attendance (%)']]
# Out:
#    Age  Attendance (%)
# 0   19              90
# 1   20              95
# 2   21              85
# 3   20              92
# 4   22              80

# %% [markdown]
# Select rows based on condition

# %%
df[df['Age']==19]
# Out:
#    Student_ID  Name  Age Gender Department  Marks  Attendance (%) Internship
# 0         101  Amit   19   Male        CSE     85              90        Yes

# %% [markdown]
# Sort Data

# %%
df.sort_values(by='Age')
# Out:
#    Student_ID   Name  Age  Gender Department  Marks  Attendance (%) Internship
# 0         101   Amit   19    Male        CSE     85              90        Yes
# 1         102  Sneha   20  Female         IT     92              95        Yes
# 3         104  Pooja   20  Female        CSE     88              92        Yes
# 2         103  Rahul   21    Male        ECE     78              85         No
# 4         105  Kiran   22    Male         ME     74              80         No

# %% [markdown]
# Describe Attributes of Data

# %%
df.describe()
# Out:
#        Student_ID        Age      Marks  Attendance (%)
# count    5.000000   5.000000   5.000000         5.00000
# mean   103.000000  20.400000  83.400000        88.40000
# std      1.581139   1.140175   7.334848         5.94138
# min    101.000000  19.000000  74.000000        80.00000
# 25%    102.000000  20.000000  78.000000        85.00000
# 50%    103.000000  20.000000  85.000000        90.00000
# 75%    104.000000  21.000000  88.000000        92.00000
# max    105.000000  22.000000  92.000000        95.00000

# %% [markdown]
# Counting Unique Values

# %%
df.nunique()
# Out:
# Student_ID        5
# Name              5
# Age               4
# Gender            2
# Department        4
# Marks             5
# Attendance (%)    5
# Internship        2
# dtype: int64
